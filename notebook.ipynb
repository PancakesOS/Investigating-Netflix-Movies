# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv", index_col = 'show_id')
netflix_df.head()
# Out:
#             type  ...             genre
# show_id           ...
# s2         Movie  ...            Dramas
# s3         Movie  ...     Horror Movies
# s4         Movie  ...            Action
# s5         Movie  ...            Dramas
# s6       TV Show  ...  International TV
#
# [5 rows x 10 columns]

# %%
#Filter movies from the 90'
movies_90 = netflix_df[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] < 2000)]

#Most frequent movie duration in the 90'
duration = int(movies_90['duration'].mode().iloc[0])
print("The most frequent movie duration in the 90' was" , duration, "min")

#Visual support graphic
movies_90['duration'].hist(bins = 20, edgecolor = 'black', color = 'darkred')
plt.title('Film duration distribution (90s)')
plt.xlabel('Duration (minutos)')
plt.ylabel('Number of movies')
plt.grid(axis='y', alpha=0.5)
plt.grid(axis='x', alpha=0.5)
plt.show()
# Out:
# The most frequent movie duration in the 90' was 94 min

# %%
#Action movies of the 90'
action_movies_90 = movies_90[movies_90['genre'] == 'Action']

#Short action movies counter
short_movie_count = len(action_movies_90[action_movies_90['duration'] < 90]) 
print('The number of movies that came out in the 90s and were less than 90 min were',short_movie_count)

#Visual support graphic
action_movies_90['duration'].hist(bins =20, edgecolor = 'black', color = 'darkred')
plt.title('Action movies duration distribution (90s)')
plt.xlabel('Duration (min)')
plt.ylabel('Number of movies')
plt.grid(axis='y', alpha=0.5)
plt.grid(axis='x', alpha=0.5)
plt.show()
# Out:
# The number of movies that came out in the 90s and were less than 90 min were 7
